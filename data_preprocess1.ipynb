# %%
import pandas as pd
import numpy as np
import tensorflow as tf

# %%
cd /gdrive/MyDrive/Colab Notebooks/sw-project
# Out:
# /gdrive/MyDrive/Colab Notebooks/sw-project

# %%
# !git clone https://MJ199999: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@github.com/MJ199999/SW-Project.git
# Out:
# Cloning into 'SW-Project'...
# remote: Enumerating objects: 37, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 37 (delta 5), reused 27 (delta 4), pack-reused 0
# Unpacking objects: 100% (37/37), done.

# %%
cd SW-Project/
# Out:
# /gdrive/MyDrive/Colab Notebooks/sw-project/SW-Project

# %%
# !git config --global user.email '02mjpark@ewhain.net'
# !git config --global user.name 'MJ199999'

# %% [markdown]
# https://velog.io/@shong676/Colab%EA%B3%BC-GitHub-%EC%97%B0%EB%8F%99%ED%95%98%EA%B8%B0

# %% [markdown]
# # 1. 데이터 불러오기

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
df = pd.read_excel('/gdrive/MyDrive/Colab Notebooks/poem.xlsx')
df.head()
# Out:
#   Unnamed: 0 Unnamed: 1                                         Unnamed: 2  \
# 0        강은교  우리가 물이 되어  우리가 물이 되어 만난다면\n가문 어느 집에선들 좋아하지 않으랴.\n우리가 키 큰 ...
# 1        김춘수   꽃을 위한 서시  나는 시방 위험한 짐승이다.\n나의 손이 닿으면 너는 \n미지의 까마득한 어둠이 된...
# 2        김춘수          꽃  내가 그의 이름을 불러 주기 전에는\n그는 다만\n하나의 몸짓에 지나지 않았다. \...
# 3        김춘수         능금  그는 그리움에 산다.\n그리움은 익어서 \n스스로도 견디기 어려운\n빛깔이 되고 향...
# 4        김춘수       부두에서  바다에 굽힌 사나이들\n하루의 노동을 끝낸\n저 사나이들의 억센 팔에 안긴\n깨지지...
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
df.columns=['시인', '제목', '시', 'Unnamed: 3']
df = df.drop(['Unnamed: 3'], axis='columns')

# %%
df.head(2)
# Out:
#     시인         제목                                                  시
# 0  강은교  우리가 물이 되어  우리가 물이 되어 만난다면\n가문 어느 집에선들 좋아하지 않으랴.\n우리가 키 큰 ...
# 1  김춘수   꽃을 위한 서시  나는 시방 위험한 짐승이다.\n나의 손이 닿으면 너는 \n미지의 까마득한 어둠이 된...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292 entries, 0 to 291
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시인      287 non-null    object
#  1   제목      291 non-null    object
#  2   시       292 non-null    object
# dtypes: object(3)
# memory usage: 7.0+ KB

# %%
print(df['시인'][df['시인'].isnull()])
print("==========")
print(df.loc[8])
print(df.loc[9])
print(df.loc[10])
print('========')
print(df.loc[10])
print(df.loc[11])
print(df.loc[12])
print(df.loc[13])
print("========")
print(df.loc[71])
print(df.loc[72])
print(df.loc[73])

# 김동환 /  김동명 김동명 김동명 / 김광섭
# Out:
# 9     NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 72    NaN
# Name: 시인, dtype: object
# ==========
# 시인                                                  김동환
# 제목                                            산 넘어 남촌에는
# 시     산 너머 남촌에는 누가 살길래\n해마다 봄바람이 남으로 오네.\n\n꽃 피는 사월이...
# Name: 8, dtype: object
# 시인                                                  NaN
# 제목                                              송화강 뱃노래
# 시     새벽 하늘에 구름장 날린다.\n에잇 에잇 어서 노 저어라, 이 배야 가자.\n구름만...
# Name: 9, dtype: object
# 시인                                                  김동명
# 제목                                                   파초
# 시     조국을 언제 떠났노.\n파초의 꿈은 가련하다.\n\n남국을 향한 불타는 향수\n너의...
# Name: 10, dtype: object
# ========
# 시인                                                  김동명
# 제목                                                   파초
# 시     조국을 언제 떠났노.\n파초의 꿈은 가련하다.\n\n남국을 향한 불타는 향수\n너의...
# Name: 10, dtype: object
# 시인                                                  NaN
# 제목                                                  수선화
# 시     그대는 차디찬 의지의 날개로\n끝없는 고독 위를 날으는\n애달픈 마음.\n\n또한 ...
# Name: 11, dtype: object
# 시인                                                  NaN
# 제목                                                내 마음은
# 시     내 마음은 호수요.\n그대 저어 오오.\n나는 그대의 흰 그림자를 안고,\n옥같이 ...
# Name: 12, dtype: object
# 시인                                            NaN
# 제목                                              밤
# 시     밤은\n푸른 안개에 싸인 호수,\n나는\n잠의 쪽배를 타고 꿈을 낚는 어부다.
# Name: 13, dtype: object
# ========
# 시인                                                  김광섭
# 제목                                                생의 감각
# 시     여명에서 종이 울린다.\n새벽 별이 반짝이고 사람들이 같이 산다.\n닭이 운다, 개...
# Name: 71, dtype: object
# 시인                                                  NaN
# 제목                                                  NaN
# 시     내\n하나의 생존자로 태어나 여기 누워 있나니\n\n한 칸 무덤 그 너머는 무한한 ...
# Name: 72, dtype: object
# 시인                                                  김광섭
# 제목                                                 해바라기
# 시     바람결보다 더 부드러운 은빛 날리는\n가을 하늘 현란한 광채가 흘러\n양양한 대기에...
# Name: 73, dtype: object

# %%
df['시인'].loc[9] = '김동환'
df['시인'].loc[11] = '김동명'
df['시인'].loc[12] = '김동먕'
df['시인'].loc[13] = '김동명'
df['시인'].loc[72] = '김광섭'

# %%
df['제목'].loc[72] = '고독'

# %%
print(df.loc[72])
print(df.info())
# Out:
# 시인                                                  김광섭
# 제목                                                   고독
# 시     내\n하나의 생존자로 태어나 여기 누워 있나니\n\n한 칸 무덤 그 너머는 무한한 ...
# Name: 72, dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292 entries, 0 to 291
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시인      292 non-null    object
#  1   제목      292 non-null    object
#  2   시       292 non-null    object
# dtypes: object(3)
# memory usage: 7.0+ KB
# None
